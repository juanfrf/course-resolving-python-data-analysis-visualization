# %% [markdown]
# # Python Foundations for Data Visualization

# %% [markdown]
# ## Create objects with data

# %% [markdown]
# ### Groceries

# %%
groceries=['pan','papel','plátanos','gel','pasta de dientes']

# %% [markdown]
# ### Price

# %%
price=[1,0.5,3,2.5,4]

# %% [markdown]
# <div class="alert alert-info">
#     The <b>function</b> processes data to give you the result you want.
#     <br><b>Libraries</b> store functions to give you results of a particular topic.
# </div>

# %% [markdown]
# ## Import matplotlib library
#
# > **Mat**hematical **Plot**ting **Lib**rary
#
# Matplotlib is a Python library that contains functions to create Data Visualizations

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Scatter plot (points)

# %%
plt.scatter(x=groceries, y=price, c='black', marker='*')

# %% [markdown]
# ### Bar plot

# %%
plt.bar(x=groceries, height=price, width=0.7, align='center')
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### Many others

# %% [markdown]
# https://matplotlib.org/stable/plot_types/index

# %% [markdown]
# ## Customize the plot

# %% [markdown]
# ### Change the size

# %%
plt.scatter(x=groceries,y=price,s=100)

# %% [markdown]
# ### Change the color

# %%
plt.scatter(x=groceries,y=price,s=500,c='black')

# %% [markdown]
# ### Change the marker

# %% [markdown]
# https://matplotlib.org/stable/api/markers_api.html

# %%
plt.scatter(x=groceries,y=price,marker='s')

# %% [markdown]
# ### Change the border

# %%
plt.scatter(x=groceries,y=price, c='white',edgecolors='black')
